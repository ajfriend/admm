# %%
# %%time
# %run timing_example.py
# Out:
# CPU times: user 47.5 s, sys: 1.33 s, total: 48.9 s
# Wall time: 52.4 s

# %%
# %matplotlib inline
from admm import ADMM, load

filename = 'test_time.json'

admm, data = load(filename)

# %%
data.keys()
# Out:
# dict_keys(['m', 'threads', 'infos', 'solve_time', 'n', 'k'])

# %%
admm.iter_breakdown()

# %%
admm.report(verbose=False)
# Out:
# Total ADMM solve time: 49.84 seconds

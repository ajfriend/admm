# %%
# %%time
# %run timing_example.py
# Out:
# CPU times: user 4.77 s, sys: 132 ms, total: 4.9 s
# Wall time: 4.96 s

# %%
# %matplotlib inline
from admm import ADMM, load

filename = 'test_time.json'

admm, data = load(filename)

# %%
print(data.keys())

data['extra'], data['solve_time']
# Out:
# dict_keys(['solve_time', 'extra', 'infos'])
# ({'filename': 'test_time.json',
#   'k': 20,
#   'm': 1000,
#   'n': 1000,
#   'seed': 0,
#   'threads': None},
#  3.8031198978424072)

# %%
admm.iter_breakdown()

# %%
admm.report(verbose=False)
# Out:
# Total ADMM solve time: 3.72 seconds

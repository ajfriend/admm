# %% [markdown]
# - put it into a function to run multiple things
# - have a dict with the settings
# - set the seed; put in dict
# - maybe some tqdm to see the progress on kona
# - a couple of sizes to see convergence, parallel speed up

# %%
# %%time
# %run timing_example.py
# Out:
# CPU times: user 4.08 s, sys: 107 ms, total: 4.19 s
# Wall time: 4.21 s

# %%
# %matplotlib inline
from admm import ADMM, load

filename = 'test_time.json'

admm, data = load(filename)

# %%
print(data.keys())

data['extra'], data['solve_time']
# Out:
# dict_keys(['extra', 'infos', 'solve_time'])
# ({'filename': 'test_time.json',
#   'k': 20,
#   'm': 1000,
#   'n': 1000,
#   'seed': 0,
#   'threads': None},
#  3.2431349754333496)

# %%
admm.iter_breakdown()

# %%
admm.report(verbose=False)
# Out:
# Total ADMM solve time: 13.18 seconds
